# %% [markdown]
# # NLP Experiment-2

# %%
# !pip install contractions
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 5.4 MB/s eta 0:00:00
# ...

# %%
import re
import nltk
import unicodedata
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tag import pos_tag
from nltk.corpus import wordnet
import contractions
import spacy

# Downloads
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
text = """
<h1>This is text for NLP Expt2.</h1>
<br>
<h2>"Hello, my name is Chaitanya Shah."</h2>
<p>I can't come to the café today for the meeting scheduled @4pm.</p>
If you're going there, you should definitely try their lattés; they are sooo goooood!!

"""

# %%
# Remove HTML Tags
soup = BeautifulSoup(text, "html.parser")
soup.get_text()
# Out:
# '\nThis is text for NLP Expt2.\n\n"Hello, my name is Chaitanya Shah."\nI can\'t come to the café today for the meeting scheduled @4pm.\nIf you\'re going there, you should definitely try their lattés; they are sooo goooood!!\n          \n'

# %%
# Remove extra whitespaces
re.sub(r'\s+', ' ', text).strip()
# Out:
# '<h1>This is text for NLP Expt2.</h1> <br> <h2>"Hello, my name is Chaitanya Shah."</h2> <p>I can\'t come to the café today for the meeting scheduled @4pm.</p> If you\'re going there, you should definitely try their lattés; they are sooo goooood!!'

# %%
# Remove accented characters (Convert accented characters to ASCII characters)
unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8')
# Out:
# '\n<h1>This is text for NLP Expt2.</h1>\n<br>\n<h2>"Hello, my name is Chaitanya Shah."</h2>\n<p>I can\'t come to the cafe today for the meeting scheduled @4pm.</p>\nIf you\'re going there, you should definitely try their lattes; they are sooo goooood!!\n          \n'

# %%
# Expand Contractions
contractions.fix(text)
# Out:
# '\n<h1>This is text for NLP Expt2.</h1>\n<br>\n<h2>"Hello, my name is Chaitanya Shah."</h2>\n<p>I cannot come to the café today for the meeting scheduled @4pm.</p>\nIf you are going there, you should definitely try their lattés; they are sooo goooood!!\n          \n'

# %%
# Remove special characters
re.sub(r'[^a-zA-Z0-9\s]', '', text)
# Out:
# '\nh1This is text for NLP Expt2h1\nbr\nh2Hello my name is Chaitanya Shahh2\npI cant come to the caf today for the meeting scheduled 4pmp\nIf youre going there you should definitely try their latts they are sooo goooood\n          \n'

# %%
# Lowercase all texts
text.lower()
# Out:
# '\n<h1>this is text for nlp expt2.</h1>\n<br>\n<h2>"hello, my name is chaitanya shah."</h2>\n<p>i can\'t come to the café today for the meeting scheduled @4pm.</p>\nif you\'re going there, you should definitely try their lattés; they are sooo goooood!!\n          \n'

# %%
# Remove numbers
re.sub(r'\d+', '', text)
# Out:
# '\n<h>This is text for NLP Expt.</h>\n<br>\n<h>"Hello, my name is Chaitanya Shah."</h>\n<p>I can\'t come to the café today for the meeting scheduled @pm.</p>\nIf you\'re going there, you should definitely try their lattés; they are sooo goooood!!\n          \n'

# %%
# Remove stopwords
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

filtered_words = [token.text for token in doc if not token.is_stop]
print("Filtered:", filtered_words)
# Out:
# Filtered: ['\n', '<', 'h1', '>', 'text', 'NLP', 'Expt2.</h1', '>', '\n', '<', 'br', '>', '\n', '<', 'h2>"Hello', ',', 'Chaitanya', 'Shah', '.', '"</h2', '>', '\n', '<', 'p', '>', 'come', 'café', 'today', 'meeting', 'scheduled', '@4pm.</p', '>', '\n', 'going', ',', 'definitely', 'try', 'lattés', ';', 'sooo', 'goooood', '!', '!', '\n          \n']

# %%
# Lemmatization
lemma = WordNetLemmatizer()
tokens = word_tokenize(text)
for word in tokens:
    print(lemma.lemmatize(word))
# Out:
# <
# h1
# >
# This
# is
# text
# for
# NLP
# Expt2.
# <
# /h1
# >
# <
# br
# >
# <
# h2
# >
# ''
# Hello
# ,
# my
# name
# is
# Chaitanya
# Shah
# .
# ``
# <
# /h2
# >
# <
# p
# >
# I
# ca
# n't
# come
# to
# the
# café
# today
# for
# the
# meeting
# scheduled
# @
# 4pm.
# <
# /p
# >
# If
# you
# 're
# going
# there
# ,
# you
# should
# definitely
# try
# their
# lattés
# ;
# they
# are
# sooo
# goooood
# !
# !

# %%
# Tokenisation
word_tokenize(text)
# Out:
# ['<',
#  'h1',
#  '>',
#  'This',
#  'is',
#  'text',
#  'for',
#  'NLP',
#  'Expt2.',
#  '<',
#  '/h1',
#  '>',
#  '<',
#  'br',
#  '>',
#  '<',
#  'h2',
#  '>',
#  "''",
#  'Hello',
#  ',',
#  'my',
#  'name',
#  'is',
#  'Chaitanya',
#  'Shah',
#  '.',
#  '``',
#  '<',
#  '/h2',
#  '>',
#  '<',
#  'p',
#  '>',
#  'I',
#  'ca',
#  "n't",
#  'come',
#  'to',
#  'the',
#  'café',
#  'today',
#  'for',
#  'the',
#  'meeting',
#  'scheduled',
#  '@',
#  '4pm.',
#  '<',
#  '/p',
#  '>',
#  'If',
#  'you',
#  "'re",
#  'going',
#  'there',
#  ',',
#  'you',
#  'should',
#  'definitely',
#  'try',
#  'their',
#  'lattés',
#  ';',
#  'they',
#  'are',
#  'sooo',
#  'goooood',
#  '!',
#  '!']

# %%
# Stemming
porter = PorterStemmer()
tokens = word_tokenize(text)
for word in tokens:
    print(porter.stem(word))
# Out:
# <
# h1
# >
# thi
# is
# text
# for
# nlp
# expt2.
# <
# /h1
# >
# <
# br
# >
# <
# h2
# >
# ''
# hello
# ,
# my
# name
# is
# chaitanya
# shah
# .
# ``
# <
# /h2
# >
# <
# p
# >
# i
# ca
# n't
# come
# to
# the
# café
# today
# for
# the
# meet
# schedul
# @
# 4pm.
# <
# /p
# >
# if
# you
# 're
# go
# there
# ,
# you
# should
# definit
# tri
# their
# latté
# ;
# they
# are
# sooo
# goooood
# !
# !

# %%
# Normalisation

# %%
# POS Tagging
tokens = word_tokenize(text)
pos_tag(tokens)
# Out:
# [('<', 'JJ'),
#  ('h1', 'NN'),
#  ('>', 'NN'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('text', 'JJ'),
#  ('for', 'IN'),
#  ('NLP', 'NNP'),
#  ('Expt2.', 'NNP'),
#  ('<', 'NNP'),
#  ('/h1', 'NNP'),
#  ('>', 'NNP'),
#  ('<', 'NNP'),
#  ('br', 'NN'),
#  ('>', 'NNP'),
#  ('<', 'NNP'),
#  ('h2', 'NN'),
#  ('>', 'NN'),
#  ("''", "''"),
#  ('Hello', 'NNP'),
#  (',', ','),
#  ('my', 'PRP$'),
#  ('name', 'NN'),
#  ('is', 'VBZ'),
#  ('Chaitanya', 'NNP'),
#  ('Shah', 'NNP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('<', 'JJ'),
#  ('/h2', 'NN'),
#  ('>', 'NNP'),
#  ('<', 'NNP'),
#  ('p', 'IN'),
#  ('>', 'NNP'),
#  ('I', 'PRP'),
#  ('ca', 'MD'),
#  ("n't", 'RB'),
#  ('come', 'VB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('café', 'NN'),
#  ('today', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('meeting', 'NN'),
#  ('scheduled', 'VBD'),
#  ('@', '$'),
#  ('4pm.', 'CD'),
#  ('<', 'NNP'),
#  ('/p', 'NNP'),
#  ('>', 'NNP'),
#  ('If', 'IN'),
#  ('you', 'PRP'),
#  ("'re", 'VBP'),
#  ('going', 'VBG'),
# ...

# %% [markdown]
# ## Complete Pre-Processing of Text

# %%
text = """
<h1>This is text for NLP Expt2.</h1>
<br>
<h2>"Hello, my name is Chaitanya Shah."</h2>
<p>I can't come to the café today for the meeting scheduled @4pm.</p>
If you're going there, you should definitely try their lattés; they are sooo goooood!!

"""

# Remove HTML Tags
soup = BeautifulSoup(text, "html.parser")
text = soup.get_text()

# Remove extra whitespaces
text = re.sub(r'\s+', ' ', text).strip()

# Remove accented characters (Convert accented characters to ASCII characters)
text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8')

# Expand Contractions
text = contractions.fix(text)

# Remove special characters
text = re.sub(r'[^a-zA-Z0-9\s]', '', text)

# Lowercase all texts
text = text.lower()

# Remove numbers
text = re.sub(r'\d+', '', text)

# Remove stopwords
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)
text = " ".join([token.text for token in doc if not token.is_stop])

print("Text after processing:\n", text)

# Lemmatization
lemma = WordNetLemmatizer()
tokens = word_tokenize(text)
lemmatized_text = " ".join([lemma.lemmatize(word) for word in tokens])
print("\nLemmatized text:\n",lemmatized_text)

# Tokenisation
tokens = word_tokenize(text)
print("\nTokenization:\n",tokens)

# Stemming
porter = PorterStemmer()
stemming_text = " ".join([porter.stem(word) for word in tokens])
print("\nPorterStemmer:\n",stemming_text)

# POS Tagging
print("\nPOS Tags:\n",pos_tag(tokens))
# Out:
# Text after processing:
#  text nlp expt hello chaitanya shah come cafe today meeting scheduled pm going definitely try lattes sooo goooood
#
# Lemmatized text:
#  text nlp expt hello chaitanya shah come cafe today meeting scheduled pm going definitely try latte sooo goooood
#
# Tokenization:
#  ['text', 'nlp', 'expt', 'hello', 'chaitanya', 'shah', 'come', 'cafe', 'today', 'meeting', 'scheduled', 'pm', 'going', 'definitely', 'try', 'lattes', 'sooo', 'goooood']
#
# PorterStemmer:
#  text nlp expt hello chaitanya shah come cafe today meet schedul pm go definit tri latt sooo goooood
#
# POS Tags:
#  [('text', 'NN'), ('nlp', 'NN'), ('expt', 'NN'), ('hello', 'NN'), ('chaitanya', 'NN'), ('shah', 'VBD'), ('come', 'JJ'), ('cafe', 'NN'), ('today', 'NN'), ('meeting', 'NN'), ('scheduled', 'VBN'), ('pm', 'NN'), ('going', 'VBG'), ('definitely', 'RB'), ('try', 'VB'), ('lattes', 'NNS'), ('sooo', 'JJ'), ('goooood', 'NN')]
