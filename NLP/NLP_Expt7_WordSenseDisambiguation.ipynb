# %% [markdown]
# # NLP Experiment-7

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet as wn
from nltk.wsd import lesk

nltk.download('wordnet')
nltk.download('punkt')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# #### Hypernyms, Hyponyms, Synonyms, Antomnyms (using Synset from WordNet):

# %%
def get_word_relations(word):
    synonyms = set()
    hypernyms = set()
    hyponyms = set()
    antonyms = set()

    synsets = wn.synsets(word)
    if not synsets:
        return list(synonyms), list(hypernyms), list(hyponyms), list(antonyms)

    for syn in synsets:
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
            if lemma.antonyms():
                for antonym in lemma.antonyms():
                    antonyms.add(antonym.name())

        for hypernym in syn.hypernyms():
            hypernyms.add(hypernym.lemma_names()[0])

        for hyponym in syn.hyponyms():
            hyponyms.add(hyponym.lemma_names()[0])

    return list(synonyms), list(hypernyms), list(hyponyms), list(antonyms)

words_input_str = input("Enter words separated by commas (e.g., bank,bat,good): ")
words = [word.strip() for word in words_input_str.split(',')]

print("\n=== Word Relations ===\n")

for word in words:
    syns, hypers, hyps, ants = get_word_relations(word)
    print(f"Word: {word}")
    print(" Synonyms:", syns if syns else "None")
    print(" Hypernyms:", hypers if hypers else "None")
    print(" Hyponyms:", hyps if hyps else "None")
    print(" Antonyms:", ants if ants else "None")
    print("-" * 50)
# Out:
# Enter words separated by commas (e.g., bank,bat,good): bank, bat, good, food, money, light, book, read, run, planet, heavy, weight
#
# === Word Relations ===
#
# Word: bank
#  Synonyms: ['cant', 'banking_company', 'camber', 'money_box', 'bank', 'coin_bank', 'savings_bank', 'bank_building', 'deposit', 'rely', 'depository_financial_institution', 'banking_concern', 'trust', 'swear']
#  Hypernyms: ['funds', 'container', 'work', 'depository', 'give', 'transact', 'ridge', 'cover', 'flight_maneuver', 'slope', 'enclose', 'act', 'array', 'tip', 'financial_institution', 'believe', 'reserve']
#  Hyponyms: ['eye_bank', 'food_bank', 'riverbank', 'agent_bank', 'credit', 'commercial_bank', 'member_bank', 'waterside', 'lean', 'lead_bank', 'soil_bank', 'blood_bank', 'merchant_bank', 'Federal_Reserve_Bank', 'vertical_bank', 'Home_Loan_Bank', 'acquirer', 'sandbank', 'piggy_bank', 'redeposit', 'credit_union', 'bluff', 'thrift_institution', 'state_bank', 'count']
#  Antonyms: ['mistrust', 'withdraw', 'distrust']
# --------------------------------------------------
# Word: bat
#  Synonyms: ['squash_racquet', 'thrash', 'drub', 'chiropteran', 'squash_racket', 'clobber', 'flutter', 'cream', 'at-bat', 'lick', 'bat', 'cricket_bat']
#  Hypernyms: ['club', 'turn', 'placental', 'blink', 'beat', 'hit', 'cricket_equipment', 'racket']
#  Hyponyms: ['carnivorous_bat', 'paddle', 'fruit_bat', 'baseball_bat', 'switch-hit']
#  Antonyms: None
# --------------------------------------------------
# Word: good
#  Synonyms: ['sound', 'dependable', 'near', 'well', 'trade_good', 'thoroughly', 'proficient', 'respectable', 'honest', 'undecomposed', 'good', 'full', 'serious', 'unspoiled', 'beneficial', 'just', 'skillful', 'effective', 'ripe', 'soundly', 'upright', 'estimable', 'commodity', 'right', 'in_effect', 'practiced', 'salutary', 'honorable', 'in_force', 'expert', 'unspoilt', 'safe', 'adept', 'secure', 'skilful', 'goodness', 'dear']
#  Hypernyms: ['quality', 'morality', 'advantage', 'artifact']
#  Hyponyms: ['benignity', 'drygoods', 'export', 'basic', 'beneficence', 'saintliness', 'common_good', 'virtue', 'merchandise', 'worldly_possession', 'fancy_goods', 'entrant', 'import', 'fungible', 'worthiness', 'wisdom', 'benefit', 'desirability', 'shopping', 'salvage', 'sporting_goods', 'summum_bonum', 'consumer_goods', 'future', 'kindness', 'better', 'optimum', 'middling']
#  Antonyms: ['badness', 'evil', 'ill', 'bad', 'evilness']
# --------------------------------------------------
# Word: food
#  Synonyms: ['food_for_thought', 'solid_food', 'intellectual_nourishment', 'food', 'nutrient']
#  Hypernyms: ['solid', 'content', 'substance']
#  Hyponyms: ['coconut', 'convenience_food', 'junk_food', 'foodstuff', 'nutriment', 'baked_goods', 'micronutrient', 'comfort_food', 'produce', 'water', 'chyme', 'seafood', 'slop', 'pasta', 'dika_bread', 'fish', 'culture_medium', 'commissariat', 'fare', 'butter', 'yolk', 'loaf', 'chocolate', 'beverage', 'health_food', 'yogurt', 'meat', 'miraculous_food', 'leftovers', 'feed', 'comestible', 'breakfast_food', 'soul_food', 'cheese', 'fresh_food', 'pabulum']
#  Antonyms: None
# --------------------------------------------------
# Word: money
#  Synonyms: ['money']
#  Hypernyms: ['medium_of_exchange', 'currency', 'wealth']
#  Hyponyms: ['token_money', 'subsidization', 'fund', 'pile', 'sterling', 'appropriation', 'boodle', 'shinplaster']
#  Antonyms: None
# --------------------------------------------------
# Word: light
#  Synonyms: ['fire_up', 'light', 'illume', 'illumination', 'unaccented', 'clean', 'clear', 'ignitor', 'faint', 'swooning', 'abstemious', 'fall', 'luminosity', 'lightheaded', 'lightness', 'wanton', 'sluttish', 'tripping', 'brightness_level', 'luminance', 'unhorse', 'twinkle', 'weak', 'unclouded', 'idle', 'lite', 'easy', 'calorie-free', 'lightsome', 'visible_light', 'brightness', 'alight', 'Christ_Within', 'spark', 'low-cal', 'sparkle', 'promiscuous', 'lighter', 'Light', 'lighting', 'light_up', 'wakeful', 'short', 'light_source', 'illumine', 'illuminate', 'perch', 'scant', 'lightly', 'get_off', 'light-headed', 'visible_radiation', 'luminousness', 'dismount', 'light-colored', 'ignite', 'loose', 'get_down', 'igniter', 'Light_Within', 'Inner_Light']
#  Hypernyms: ['land', 'illumination', 'physical_property', 'insight', 'fall', 'ethical_motive', 'visual_signal', 'actinic_radiation', 'source_of_illumination', 'condition', 'expression', 'burn', 'vitality', 'visual_property', 'scene', 'descend', 'public_knowledge', 'friend', 'lighten', 'ignite', 'position', 'device']
#  Hyponyms: ['counterglow', 'headlight', 'theater_light', 'moonlight', 'luminescence', 'streamer', 'half-light', 'panel_light', 'incandescence', 'navigation_light', 'room_light', 'blinker', 'strip_lighting', 'meteor', 'aura', 'kindle', "friar's_lantern", 'fluorescence', 'sunniness', 'torchlight', 'floodlight', 'lamplight', 'torch', 'gaslight', 'searchlight', 'highlight', 'beam', 'twilight', 'houselights', 'brightness', 'match', 'traffic_light', 'fuse', 'night-light', 'light_up', 'glow', 'firelight', 'corona', 'reignite', 'spotlight', 'scintillation', 'anchor_light', 'daylight', 'starlight', 'sconce', 'jacklight', 'cigar_lighter', 'flood', 'radiance', 'flare_up', 'fairy_light', 'illuminance', 'candlelight', 'sunlight', 'sidelight']
#  Antonyms: ['extinguish', 'dark', 'heavy']
# --------------------------------------------------
# Word: book
#  Synonyms: ['Koran', 'record_book', 'playscript', 'Quran', 'Bible', 'book', 'record', 'Book', 'rule_book', "al-Qur'an", 'volume', 'Christian_Bible', 'hold', 'Word_of_God', 'script', 'Word', 'Holy_Writ', 'ledger', 'reserve', 'Good_Book', 'Scripture', 'Holy_Scripture', 'account_book', 'leger', 'book_of_account']
#  Hypernyms: ['product', 'request', 'register', 'record', 'sacred_text', 'collection', 'section', 'fact', 'schedule', 'publication', 'dramatic_composition']
#  Hyponyms: ['notebook', 'subsidiary_ledger', 'pop-up_book', 'review_copy', 'general_ledger', 'keep_open', 'catalog', 'phrase_book', 'order_book', 'playbook', 'picture_book', 'folio', 'textbook', 'promptbook', 'booklet', 'copybook', 'shooting_script', 'cost_ledger', 'card', 'authority', 'journal', 'libretto', 'appointment_book', 'novel', 'Epistle', 'scenario', 'workbook', 'screenplay', 'bestiary', 'hardback', 'reference_book', 'curiosa', 'continuity', 'catechism', 'family_Bible', 'daybook', 'prayer_book', 'album', 'yearbook', 'sketchbook', 'storybook', 'coffee-table_book', 'tome', 'won-lost_record', 'paperback_book', 'ticket', 'formulary', 'trade_book', 'logbook', 'songbook', 'dialogue']
#  Antonyms: None
# --------------------------------------------------
# Word: read
#  Synonyms: ['read', 'register', 'record', 'scan', 'interpret', 'understand', 'learn', 'say', 'study', 'translate', 'show', 'take']
#  Hypernyms: ['indicate', 'interpret', 'talk', 'understand', 'audition', 'publication', 'predict', 'have']
#  Hyponyms: ['audit', 'dictate', 'strike', 'numerate', 'decipher', 'skim', 'train', 'call', 'show', 'reread', 'say', 'anagram', 'scry', 'drill', 'misread', 'lipread', 'dip_into']
#  Antonyms: None
# --------------------------------------------------
# Word: run
#  Synonyms: ['work', 'endure', 'footrace', 'function', 'head_for_the_hills', 'ladder', 'trial', 'unravel', 'scat', 'flow', 'black_market', 'bleed', 'test', 'go', 'persist', 'campaign', 'lam', 'run_away', 'escape', 'pass', 'move', 'lean', 'outpouring', 'operate', 'prevail', 'execute', 'streak', 'guide', 'range', 'rill', 'hunt_down', 'bunk', 'runnel', 'streamlet', 'rivulet', 'tend', 'race', 'foot_race', 'course', 'melt', 'running', 'ravel', 'lead', 'discharge', 'political_campaign', 'running_play', 'running_game', 'melt_down', 'fly_the_coop', 'extend', 'run_for', 'track_down', 'ply', 'scarper', 'draw', 'take_to_the_woods', 'die_hard', 'incline', 'hightail_it', 'hunt', 'feed', 'play', 'tally', 'carry', 'turn_tail', 'run', 'be_given', 'consort', 'break_away']
#  Hypernyms: ['disintegrate', 'function', 'stream', 'accompany', 'incur', 'occur', 'succession', 'flow', 'sail', 'attempt', 'liberty', 'diffuse', 'pass', 'time_period', 'move', 'travel', 'free', 'break', 'sequence', 'enforce', 'last', 'compete', 'change', 'travel_rapidly', 'succeed', 'score', 'become', 'race', 'trade', 'capture', 'locomotion', 'circulate', 'carry_through', 'process', 'football_play', 'indefinite_quantity', 'continue', 'dissolve', 'damage', 'run', 'direct', 'leave', 'trip', 'be']
#  Hyponyms: ['scrounge', 'work', 'gutter', 'stream', 'warm_up', 'scurry', 'rush', 'falcon', 'obstacle_race', 'clinical_trial', 'hawk', 'assay', 'speed_skate', 'Snellen_test', 'roll', 'skedaddle', 'eddy', 'jacklight', 'foxhunt', 'double', 'take_kindly_to', 'waste', 'seep', 'still-hunt', 'go_far', 'block', 'losing_streak', 'marathon', 'escape', 'tide', 'poach', 'flee', 'trot', 'streak', 'outrun', 'spill', "governor's_race", 'pilot_project', 'drain', 'course', 'fuse', 'fitting', 'circulate', 'print_run', 'pour', 'drive', 'return', 'draw', 'winning_streak', 'jog', 'audition', 'run', 'hare', 'cross-file', 'suffer', 'steeplechase', 'thread', 'field_trial', 'try', 'rerun', 'ferret', 'reverse', 'stump', 'turtle', 'horse-race', 'snipe', 'gravitate', 'come', 'MOT', 'trickle', 'senate_campaign', 'run_bases', 'jet', 'flush', 'reverberate', 'show', 'cut', 'crock', 'seal', 'lope', 'double_blind', 'carry_over', 'sprint', 'end_run', 'campaign', 'rub', 'boat-race', 'run_batted_in', 'whistlestop', 'service', 'whale', 'track_event', 'funrun', 'rabbit', 'preclinical_trial', 'run-time', 'romp', 'radiate', 'place', 'unearned_run', 'run_down', 'step', 'dash', 'fowl', 'earned_run', 'financier']
#  Antonyms: ['idle', 'malfunction']
# --------------------------------------------------
# Word: planet
#  Synonyms: ['planet', 'satellite', 'major_planet']
#  Hypernyms: ['follower', 'celestial_body']
#  Hyponyms: ['morning_star', 'inferior_planet', 'terrestrial_planet', 'Jovian_planet', 'superior_planet', 'outer_planet']
#  Antonyms: None
# --------------------------------------------------
# Word: heavy
#  Synonyms: ['grueling', 'gruelling', 'sound', 'weighed_down', 'arduous', 'grievous', 'operose', 'big', 'gravid', 'leaden', 'punishing', 'dense', 'toilsome', 'labored', 'lowering', 'enceinte', 'backbreaking', 'laboured', 'fleshy', 'heavy', 'expectant', 'overweight', 'threatening', 'intemperate', 'with_child', 'impenetrable', 'ponderous', 'wakeless', 'hard', 'profound', 'grave', 'sonorous', 'heavily', 'laborious', 'large', 'cloggy', 'lumbering', 'clayey', 'great', 'sullen', 'weighty']
#  Hypernyms: ['actor', 'character']
#  Hyponyms: None
#  Antonyms: ['light']
# --------------------------------------------------
# Word: weight
#  Synonyms: ['weighting', 'weight_unit', 'weight_down', 'burden', 'exercising_weight', 'angle', 'burthen', 'weightiness', 'system_of_weights', 'free_weight', 'slant', 'weight']
#  Hypernyms: ['oppression', 'charge', 'coefficient', 'bias', 'artifact', 'physical_property', 'system_of_measurement', 'importance', 'sports_equipment', 'unit_of_measurement']
#  Hyponyms: ['plumb', 'makeweight', 'welterweight', 'tare', 'picul', 'counterweight', "apothecaries'_unit", 'arroba', 'sinker', 'lightness', 'dumbbell', 'oka', 'rotl', 'troy', 'avoirdupois', 'catty', 'crith', 'last', 'saddle', 'load', 'frail', 'pood', 'troy_unit', 'heaviness', 'maund', 'throw-weight', 'overburden', 'paperweight', 'tod', 'tael', 'obolus', 'dead_weight', 'barbell', 'bob', 'body_weight', 'poundage']
#  Antonyms: ['unburden']
# --------------------------------------------------

# %% [markdown]
# ### Word Sense Disambiguation (WSD):

# %%
def lesk_wsd(sentence, target_word):
    tokens = word_tokenize(sentence.lower())
    best_synset = lesk(tokens, target_word)

    if best_synset:
        return best_synset, best_synset.definition()
    else:
        return None, None

sentence = input("Enter a sentence: ")
target_word = input("Enter the target word to disambiguate: ")

best_synset, definition = lesk_wsd(sentence, target_word)

if best_synset:
    print(f"\nBest Synset for '{target_word}': {best_synset.name()}")
    print(f"Definition: {definition}")
else:
    print(f"\nCould not find a suitable synset for '{target_word}'.")
# Out:
# Enter a sentence: He deposited 500,000 USD in the bank.
# Enter the target word to disambiguate: bank
#
# Best Synset for 'bank': savings_bank.n.02
# Definition: a container (usually with a slot in the top) for keeping money at home

# %%
print("-"*20+"Word Sense Disambiguation with Lesk"+"-"*20)

sentences = [
    ("bank", "He deposited the money in the bank."),
    ("bank", "They sat on the bank of the river."),
    ("bat", "The bat flew out of the cave."),
    ("bat", "He hit the ball with a bat."),
    ("light", "This box is very light."),
    ("light", "She turned on the light to read."),
    ("book", "I will book a ticket for the show."),
    ("book", "He read a fascinating book."),
]

for word, sent in sentences:
    sense = lesk(nltk.word_tokenize(sent), word)
    print(f"\nSentence: {sent}")
    print(f"\tPredicted sense: {sense.name()} -> {sense.definition()}")
    print()
# Out:
# --------------------Word Sense Disambiguation with Lesk--------------------
#
# Sentence: He deposited the money in the bank.
# 	Predicted sense: savings_bank.n.02 -> a container (usually with a slot in the top) for keeping money at home
#
#
# Sentence: They sat on the bank of the river.
# 	Predicted sense: bank.v.07 -> cover with ashes so to control the rate of burning
#
#
# Sentence: The bat flew out of the cave.
# 	Predicted sense: cricket_bat.n.01 -> the club used in playing cricket
#
#
# Sentence: He hit the ball with a bat.
# 	Predicted sense: bat.v.01 -> strike with, or as if with a baseball bat
#
#
# Sentence: This box is very light.
# 	Predicted sense: luminosity.n.01 -> the quality of being luminous; emitting or reflecting light
#
#
# Sentence: She turned on the light to read.
# 	Predicted sense: luminosity.n.01 -> the quality of being luminous; emitting or reflecting light
#
#
# Sentence: I will book a ticket for the show.
# 	Predicted sense: script.n.01 -> a written version of a play or other dramatic composition; used in preparing for a performance
#
#
# Sentence: He read a fascinating book.
# 	Predicted sense: script.n.01 -> a written version of a play or other dramatic composition; used in preparing for a performance
